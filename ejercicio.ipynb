# %% [markdown]
# <a href="https://colab.research.google.com/github/mc-tz/Vision-artificial/blob/main/ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/institutohumai/cursos-python/blob/master/AnalisisDeDatos/1_Indexing/ejercicio/ejercicio_solucion.ipynb"> <img src='https://colab.research.google.com/assets/colab-badge.svg' /> </a>
# <div align="center"> Recordá abrir en una nueva pestaña </div>
#
#
# Para este ejercicio vamos a importar un conjunto de datos con el listado de colegios públicos de Bogotá del año 2016

# %% [markdown]
# # Ejercicio I: base de Colegios de Bogotá.

# %%
import pandas as pd
import numpy as np

# %%
df_colombianos= pd.read_csv('/content/Colombianos_registrados_en_el_exterior_20250905.csv')

# %% [markdown]
# ¿Cuáles son las columnas? ¿Cuántas filas tiene?

# %%
df_colombianos.columns
# Out:
# Index(['País', 'Código ISO país', 'Ciudad de Residencia',
#        'Oficina de registro', 'Grupo edad', 'Edad (años)', 'Área Conocimiento',
#        'Sub Area Conocimiento', 'Nivel Académico', 'Estado civil', 'Género',
#        'Etnia de la persona', 'Estatura (CM)', 'Ciudad de Nacimiento',
#        'Localización', 'Fecha de Registro', 'Cantidad de personas'],
#       dtype='object')

# %%
df_colombianos.shape
# Out:
# (566630, 17)

# %% [markdown]
# Seleccionen los colegios donde la propiedad de la planta física sea de una persona natural o comunidad religiosa.

# %%
df_colombianos.sample(10)
# Out:
#                   País Código ISO país     Ciudad de Residencia  \
# 464889          CANADA             CAN            QUEBEC/QUEBEC
# 112308            PERU             PER    LORETO/IQUITOS MAYNAS
# 310819  ESTADOS UNIDOS             USA  RHODE ISLAND/WOONSOCKET
# 505791         ECUADOR             ECU          PICHINCHA/QUITO
# 419814  ESTADOS UNIDOS             USA        NEW YORK/BROOKLYN
# 64289           ESPA�A             ESP       CATALU�A/BARCELONA
# 366853        ALEMANIA             DEU     BERLIN/BERLIN-PANKOW
# 552001          ESPA�A             ESP            MADRID/MADRID
# 522528         ECUADOR             ECU          PICHINCHA/QUITO
# 95988   ESTADOS UNIDOS             USA    FLORIDA/WESLEY CHAPEL
#
#        Oficina de registro    Grupo edad  Edad (años)  \
# 464889         C. MONTREAL        ADULTO           32
# 112308          C. IQUITOS        ADULTO           31
# 310819           C. BOSTON        ADULTO           40
# 505791            C. QUITO        ADULTO           30
# 419814       C. NUEVA YORK  ADULTO JOVEN           26
# 64289         C. BARCELONA        ADULTO           39
# 366853           C. BERLIN  ADULTO JOVEN           25
# 552001           C. MADRID        ADULTO           38
# 522528            C. QUITO  ADULTO JOVEN           25
# 95988           C. ORLANDO  ADULTO JOVEN           28
#
#                                    Área Conocimiento  \
# 464889                                     NO INDICA
# 112308                                       NINGUNA
# 310819  ECONOM�A, ADMINISTRACI�N CONTADURIA Y AFINES
# 505791                                       NINGUNA
# 419814                                       NINGUNA
# 64289                                        NINGUNA
# 366853                                       NINGUNA
# 552001                   CIENCIAS SOCIALES Y HUMANAS
# 522528                   CIENCIAS SOCIALES Y HUMANAS
# 95988                                      NO INDICA
#
#                                 Sub Area Conocimiento  \
# 464889                                      NO INDICA
# 112308                                        NINGUNA
# 310819                                 ADMINISTRACI�N
# 505791                                        NINGUNA
# 419814                                        NINGUNA
# 64289                                         NINGUNA
# 366853                                        NINGUNA
# 552001  OTROS ESTUDIOS EN CIENCIAS SOCIALES Y HUMANAS
# 522528                               DERECHO Y AFINES
# 95988                                       NO INDICA
#
#                        Nivel Académico Estado civil     Género  \
# 464889          PREGRADO - PROFESIONAL      SOLTERO  MASCULINO
# 112308                    BACHILLERATO      SOLTERO  MASCULINO
# 310819  PREGRADO - T�CNICO PROFESIONAL  DESCONOCIDO   FEMENINO
# 505791                       NO INDICA      SOLTERO  MASCULINO
# 419814                    BACHILLERATO      SOLTERO  MASCULINO
# 64289                        NO INDICA      SOLTERO  MASCULINO
# 366853                       NO INDICA      SOLTERO   FEMENINO
# 552001           POSTGRADO - DOCTORADO      SOLTERO   FEMENINO
# 522528                       NO INDICA      SOLTERO   FEMENINO
# 95988                        NO INDICA  DESCONOCIDO  MASCULINO
#
#          Etnia de la persona  Estatura (CM)  \
# 464889  SIN ETNIA REGISTRADA            166
# 112308                  OTRO             -1
# 310819  SIN ETNIA REGISTRADA            156
# 505791               NINGUNA             -1
# 419814                  OTRO             -1
# 64289                NINGUNA             -1
# 366853               NINGUNA             -1
# 552001               NINGUNA             -1
# 522528               NINGUNA             -1
# 95988   SIN ETNIA REGISTRADA            170
#
#                      Ciudad de Nacimiento              Localización  \
# 464889    COLOMBIA/ATLANTICO/BARRANQUILLA  (56.130366, -106.346771)
# 112308  COLOMBIA/NORTE DE SANTANDER/OCA�A   (-9.189967, -75.015152)
# 310819         COLOMBIA/BOLIVAR/CARTAGENA    (37.09024, -95.712891)
# 505791             COLOMBIA/NARI�O/CUMBAL   (-1.831239, -78.183406)
# 419814      COLOMBIA/VALLE DEL CAUCA/CALI    (37.09024, -95.712891)
# 64289       COLOMBIA/VALLE DEL CAUCA/CALI     (40.463667, -3.74922)
# 366853             COLOMBIA/CAUCA/POPAYAN    (51.165691, 10.451526)
# 552001                  ITALIA/LAZIO/ROMA     (40.463667, -3.74922)
# 522528            ECUADOR/PICHINCHA/QUITO   (-1.831239, -78.183406)
# 95988        COLOMBIA/CUNDINAMARCA/BOGOTA    (37.09024, -95.712891)
#
#        Fecha de Registro  Cantidad de personas
# 464889           2014-11                     1
# 112308           2023-03                     1
# 310819           2023-11                     1
# 505791           2017-11                     1
# 419814           2024-10                     1
# 64289            2022-02                     1
# 366853           2021-09                     1
# 552001           2014-04                     1
# 522528           2019-06                     1
# 95988            2015-12                     1

# %% [markdown]
# ¿Hay alguno de estos colegios que sea para capacidades excepcionales?

# %%
df_colombianos.head(5)
# Out:
#              País Código ISO país             Ciudad de Residencia  \
# 0           CHILE             CHL                  COQUIMBO/OVALLE
# 1  ESTADOS UNIDOS             USA               NEW YORK/MANHATTAN
# 2  ESTADOS UNIDOS             USA  DISTRICT OF COLUMBIA/WASHINGTON
# 3  ESTADOS UNIDOS             USA                      NEVADA/RENO
# 4          ESPA�A             ESP                  CATALU�A/GIRONA
#
#   Oficina de registro    Grupo edad  Edad (años)  \
# 0         C. SANTIAGO        ADULTO           32
# 1       C. NUEVA YORK  ADULTO JOVEN           28
# 2       C. WASHINGTON  ADULTO JOVEN           27
# 3    C. SAN FRANCISCO        ADULTO           35
# 4        C. BARCELONA        ADULTO           35
#
#                               Área Conocimiento  \
# 0                                       NINGUNA
# 1  ECONOM�A, ADMINISTRACI�N CONTADURIA Y AFINES
# 2  ECONOM�A, ADMINISTRACI�N CONTADURIA Y AFINES
# 3                   CIENCIAS SOCIALES Y HUMANAS
# 4                          CIENCIAS DE LA SALUD
#
#                            Sub Area Conocimiento         Nivel Académico  \
# 0                                        NINGUNA               NO INDICA
# 1                                       ECONOM�A  PREGRADO - TECNOL�GICO
# 2                                 ADMINISTRACI�N               NO INDICA
# 3  OTROS ESTUDIOS EN CIENCIAS SOCIALES Y HUMANAS    POSTGRADO - MAESTRIA
# 4                                       MEDICINA  PREGRADO - PROFESIONAL
#
#   Estado civil    Género Etnia de la persona  Estatura (CM)  \
# 0       CASADO  FEMENINO             NINGUNA             -1
# 1       CASADO  FEMENINO             NINGUNA             -1
# 2      SOLTERO  FEMENINO             NINGUNA             -1
# 3       CASADO  FEMENINO             NINGUNA             -1
# 4  UNION_LIBRE  FEMENINO             NINGUNA             -1
#
#                Ciudad de Nacimiento              Localización  \
# 0     COLOMBIA/VALLE DEL CAUCA/CALI  (-35.675147, -71.542969)
# 1        COLOMBIA/RISARALDA/PEREIRA    (37.09024, -95.712891)
# 2  COLOMBIA/SANTANDER/FLORIDABLANCA    (37.09024, -95.712891)
# 3      COLOMBIA/CUNDINAMARCA/BOGOTA    (37.09024, -95.712891)
# 4                     (NO REGISTRA)     (40.463667, -3.74922)
#
#   Fecha de Registro  Cantidad de personas
# 0           2021-04                     1
# 1           2023-10                     1
# 2           2022-06                     1
# 3           2024-02                     1
# 4           2024-09                     1

# %% [markdown]
# ¿Cuáles son los colegios que ofrecen todos los niveles educativos? ¿Qué idiomas ofrecen?
